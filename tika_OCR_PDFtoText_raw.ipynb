# %% [markdown]
# <a href="https://colab.research.google.com/github/jennkimerson/OCR_ArchivalDataOrganization_HGARC/blob/mk1/tika_OCR_PDFtoText_raw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tika
# Out:
# Requirement already satisfied: tika in /usr/local/lib/python3.6/dist-packages (1.19)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from tika) (2.18.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from tika) (40.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->tika) (2018.11.29)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->tika) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->tika) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->tika) (3.0.4)

# %%
from tika import parser

raw = parser.from_file('sample.pdf')
print(raw['content'])
# Out:
# 2019-03-01 17:20:44,714 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server/1.19/tika-server-1.19.jar to /tmp/tika-server.jar.
# 2019-03-01 17:20:47,297 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server/1.19/tika-server-1.19.jar.md5 to /tmp/tika-server.jar.md5.
# 2019-03-01 17:20:47,526 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# 2019-03-01 17:20:52,534 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
#
#
#
#
# The Inventory
#
#
# of the
#
#
# Eugene Burdick
#
#
# Collection
#
#
# #32
#
#
#
#
#
#
#
# Howard Gotlieb Archival Research Center
#
#
#
#
#
#
#
# t>OX 1
#
# Eugene Burdick 1918 -
#
# ,- •· :
# Ninth Wave.
#
# corr. with pub.
#
# outline
#
# 1956 Typescript..., .: . -~·~_,.. .. .-.,.· "
#
# 16 fo]ders - Draft 1 by chapters 1947 [1-8, 16-22, misci!.I. chapt~r.sJ
#
# 8 fqlrl;rs - Pa.rt II Chapt 1 - 3, notes on 4, notes, t'l.ble of contents
#
# ' 4;.~ _,lie#
#
# Box 2.,3,4 30 folc1,;rs - Chapt. 1 - 30 Chapt 1 bas t. and carbons nnd one t. with minor
#
# Box 4
#
# .Box 5
#
# Box 1
#
# Box 5
#
# ed. changes (pub's copy?)
#
# 4 folders - "Ninth Wave", "Eye of Sea Gull" 1936, 1942, Election year, IDs
#
# Angeles today, 1944
#
# folder - galleys
#
# folder - Book format
#
# folder - Music ~core with TIS from P. S. Odegard who d~.d scores incl.
#
# folder - clippings of reviews
#
# folder - Preface to Japanese ed. t. 2 /.. dated Se 1964 and c. copy with
#
# corrections indicated in other copy.
#
# folder - Preliminary COIT. Houghton 1955-56
#
# tncl. dra:f't (holo.) of E B.J ~elegram to (R. Wilson) at publishers
#
# corr re its being BOM choice 1956 and copy of BOM announcement also
#
# re its :Sng. publ.
# folder - contracts
#
# folder - publicity
#
# folder - fan mail
#
# folder - movie corr.
#
# folder - motion picture notes - bolo. 18_{.
#
# folder - motion pict. script t. c. on yellow paper.
#
#
#
# J ::1 ; no. 2
# ..._ .J
#
# Nina's Book 1964
#
# Box 6-12 folder Correspondence 1963 - 65
#
# Incl. editorial questions on text
#
# 1
# folder Notes - t. and hole. £. parts of' chapte'rs, etc.
#
# folder Introd. - several copies and drafts int. and t. c.
#
# 24 folders Chapters 1 - 24, t. and carbons
#
# folder Concentration camp sequence chapts. 1 - 7 (xerox copies)
#
# folder Recording "A Day with Nina" each with record and t. version of text.
#
# folder 2 Recordings "The Grease of Excellence"
#
# folder 3 Recordings "The Camp in the Forest"
#
# folder 2 Recordings "Victory of the Believers"
#
# folder 2 Recordings "Kapos"
#
# folder 3 Recordings "Days of 1500 Calories"
#
# folder 1 Recording "Days of Long and Short"
#
# folder 1 Recording "Advice to a Prince"
#
# folder 2 Recordings "Quality of Warmth"
#
# folder 3 Recordings "Rabbit Hunters"
#
# folder 3 Recordings "Big House"
#
# folder 2 Recordings "Hole in the Wall of History"
#
# @!!~- Book ... ( mss) t. publishers copy 510 i .
#
# Envelope of clips of review of N's B
#
# Galleys of~ 2! Capricorn 1961
#
#
#
# §o.
# Box 13-16
#
# loose
#
# 3J Blue of Capricorn 1961
# Folder - Notes· incl. t. on how he came to write this, holo. I,. copy
#
# of jacket. Incl. t. letter signed "Bud" to his wife - written
#
# during war, incl. acc. of meeting with Kuper on the island.
#
# Folder - Drafts (xerox copies and t. c. )
#
# Folder - Introd. t.
#
# 18 Folders - Cha.pt. 1 - 18 some in several copies t. and c.
#
# Folder - Turnby Walker Treatment [movie.J t. c.
#
# Folder - Film negotiations 1964
#
# Folder - Fan mail
#
# Folder - Clippings of review. incl. photosta.ts, records of adv.
#
# Folder - Promotion corr. etc. re its publishing 1960 - 61
#
# Folder - Correspondence with Houghton, contracts
#
# Blue of Capricorn, recordings with t. of text
#
# 3_Folders -"M:l.dness of the Ninety - Eight"
#
# Folder - "Jack Nash"
#
# 3 Folders - "High Islands"
#
# 2 Folders- "Black and White"
#
# 4 Folders - "Lincoln Carver Bonaparte"
#
# TyJ;iescript {342 iJ some ed. corr. publisher's copy
# Ga.lleys "Author's file" in pencil
#
# Galleys - Author's proof
#
# Galleys - set in page proof with proofs of 1lluE.fto11o,-.s
#
# Kerker, T. w. TIS 1962 incl. pictures of so. sea island and people
#
# taken during World War II
#
#
#
# Eugene Burdick
# File no. 4 Ugly American
#
# folder
#
# Box 17¥
# ✓
#
# Corr. Norton, BOMC, Books Abridged etc. - 1958/59
#
# " YNorton Asian Book corr. incl. contra.eta
#
# II
#
# ft
#
# n
#
# ft
#
# rr
#
# ff
#
# ff
#
# "
#
# "
#
# "
#
# -
#
# 2 pen sketches by Thomas Aida.la (artist)
#
# V Corr. Iederer • Burdick 1958/59
#
# J Business 1961 records
#
# " Englund, George - corr. 1959 ( Universal International Pict.)
#
# v General corr. movie incl. Nat. Screen Cm.me il Award as best movie of
#
# month l\By, 1963
#
# ~ Publicity - movie
#
# o Bwanson, H N Movie
#
# 0 Contracts and f~ial records. Curtis Brown, Norton
#
# v Business - Martin Gang 1959/60
#
# J Murrow, E. R. and F. W. Friendly
#
# Murrow 1 TIS 1959
#
# corr. re its being on CBS
#
# J Reviews
#
# ...; Play version - Book reviews, T V
#
# incl. Turnlo/ Walker script for book review on Video Tape CBS
#
# mimeo c. of Beards~, Phyllis Pass By this House (play)
#
# ~' I ~ v Screen Play 1st draft 1959 mimeo
#
# "
#
# incl. "The Beautiful American" by Englund
#
# ✓ Dissent Episode incl. copy of journal Dissent Sunnner' 59
#
# critique of U. A., clips with t.c. of replies to Sen.
#
# Fulbright's criticism in Senate
#
#
#
# Boxes ~ /0,
# folder
#
# If
#
# "
#
# "
#
# "
#
# "
# ti
#
# Boy ;).('3 " s
#
# It
#
# ✓ Sat.Post incl. copies (t.c.} of article
#
# Fulbright episode 1959 incl. TIS from J W Fulbright 1959 with c. of
#
# speech on U. A. to be given in Senate
# mimeo
#
# v Burdick/Iederer reply to JW Fulbright [ extra4 cop1'Jes of lette1J
#
# /Miscell. clippings ~ speeches
# ✓Publicity
#
# ✓ Some Ugly Americans ~. c. of a.rticl~
#
# Play, Bernard Lubar text t.c.
#
# and proof for pub. of ·~. p. and final draft for pub.
#
# Fan ma.il ,;;,_../ij :J<.., o~ I], C,tf <;
# Nimitz, Chester W 3 A.IS 1958 4 p. and l p. 2'{.
#
# Yzellerback, J D TIS 1960 5 P•
#
# v M9.nsfield, MikeTI.S 1958 1 p.
# ✓Lehman, Herbert H TIS 1958 2 p.
#
# ✓shelby, John F (House} TIS 1959
#
# v Anderson, Frederdck L TIS 1959
#
# ✓Roosevelt, Eleanor TIS 1958
#
# v Hogg, Jimmy (Admiral) TIS 1959
# r.:;,
#
# 0
# ~ ~J v W<Jllf!., Pl.dip Pf.~t-c-C'op-1 ... J Alr4°" Od H, J 9;;,:_:--
#
# u .,. tt:;... -✓ Editorials, newdpaper comm.erlts, naga.zines, etc.
#
# tJ Kennedy, John (Senate) TIS 1959
#
# ✓ Gruening, Ernest (Senate) TIS 1959
#
# copies of senate speeches, etc.
#
# " /Research incl. clips, notes, etc.
#
# "
#
# Shaw, W. David AI.B 1958 incl. sketch pencil for illus. for
#
# Readers Digest version of U. A.
#
# Miscl. notes incl. corr., clips holo. notes some xerox pages of proofs
#
# text marked "Burdick version, Dec 21, 1957 t. c.
#
#
#
# ..J ·
#
# Boxes~
#
# r.5;!;72.z_
# 8 " s
#
# II
#
# "
#
# text marked "Burdick version, Dec 24, 1957 tor of
#
# "How to Buy an American"
#
# versions of Jan 4, 1958 t. c. a.nd other xerox page S
# ,...
#
# ~
#
# Chapter :']3) 13A, 15 - 21
# _ _.,.,.
#
# Epilogue t. drafts and t.c.
#
# Corrected ms. t.
#
# · ✓" Galleys
#
# ✓i, Life Article - Foreign Aid a.nd the Ugly American 1959/62
#
# incl. t. c. with holo. revision by B. L. and other draf't.s.
#
# ✓ " "U. A. on New Frontier", 1961
#
# "' 1011 s
#
# ✓ LoBse
#
# ✓Loose
#
# 1st rough draft, prel. notes etc. corr. and material coll. as
#
# background information.
#
# Life article "From Novel to Movie 11, 1963 incl. corr. and text in
#
# several copies.
#
# of' recordings with t. of text
#
# Galleys [~ked)
#
# Ugly American. bolo. t. J • a.nd t. of text of ms.
# ~- . ~·------ ~ . -~-·. - . --- .---~· -- ~·-· - . '. ' - ------ ... ·-----·-·--·
#
#
#
# IJUACO JV-JJ
#
# file no.· 5 Sarkhan [nove1][Rt. iJ
# :rhe front of file is cong;,osed of a large sampling of background
#
# material in form of pamphlets, clips, Congressio.naJ. hearings,
#
# articles, propaganda pieces, periodicals.
#
# Brademas, John (House) TIS 1960 and encl. of speech
#
# tQC. of "Russian Propaganda." by E B and Iederer
#
# copy of U S Array area Handbook for Vietnam
#
# Vietnamese song book. U 8 Arm;r language School
#
# t • c. of Iederer to E B ~ books plan development Nov 61
#
# ( in Box in file) Sarkhan. xerox c. of t. 354 . .£.
# jacket proof
#
# galleys unmarked duplicate ~t
#
# file no. 6 Sarkhan [?t 2J
# 34 folders Chapters 1 - 33, [Cb.apt. 5, has 2 folder~ having various drafts
#
# Boxes 24-29
#
# folder
#
# folder
#
# folder
#
# folder
#
# folder
#
# folder
#
# folder
#
# in t., t. c. and xerox copies. d4scards, re-writes by B or L and
#
# Kuhn mostly dated (Kuhn is ed. at ~Graw Hill)
#
# Miscell. notes holo. and t. of B's, inserts, cancels
#
# notes on who is to re-write which parts
#
# Preface - variant drafts - dated
#
# Book Correspondence 1961 - 65 with Mu-tin Gang's compa.ny (agents)
#
# ~Graw Hill.Inc. "Prospectus" of novel
#
# Iederer, w. J. TIS several
# Royal Council M?eting [!. .e. pa.rt o-;f boo~] t. c. April, 1965
#
# with preL notes a.nd outline
#
# Scenes and sequences - t. material for discs.
#
# Sarkhan outline - various dra.t'ts, dated t. a.nd xerox copies
#
# Washington Confrontation - variant dra.t'ts, dated t. with t. c. and
#
# hole. corr. and additions.
#
#
#
# Eugene Burdick
#
# Boxes 34-39
#
# File [no. 7_) "480"
# folder Research - clips, articles ~- Simulmatics corp. reports.
#
# folder
#
# ·- folder
#
# folder
#
# folder
#
# 24 folders
#
# 2 folders
#
# loose
#
# Correspondence - 1963/64 incl. t.c. of E B to pub. on publicity
#
# angles he is suggesting and corr. concerned with serial rights etc.
#
# review list of persons to whom book was sent.
#
# Film version negotiations 1964. ( letro Goldwyn ~yer)
#
# Fan Mail incl. xerox copies of wviews from ~Graw, clips of
#
# advertisements and reviews [really only l or 2 fan letters, primarily
#
# reviews~
# visi 01\S
#
# General notes - holographs and t. outline notes for re. Ii.Mr, Feb. 20.
#
# preface draft, t. leaves with printer's directions, other da.ted notes
#
# in t. with holo. ann.
#
# Cha.pt. 1 - 24 Final
#
# otdeR..
# ea.ch ftt may have several da.ted early drafts, inserts,~- t. and
#
# xerox copies with holo. annotations. Final copyi has printer's marks.
#
# 2 discs with t. text "Outline for final chapters"
#
# page proofs of "Candidates, Issues and Strategies" by Ithiel de John
#
# Pool and others. 1964 sent to EB for intormatbn
# rR.eJim.
#
# master galleys of "480", layout of t. page and :p;ib-. L.
#
# envelope of.clips.
#
# r ... ..
#
#
#
# folder v Hook, Sidney
#
# Boxes 40~
# clips on his "Fail - Safe Fa..U.a.cy" 1963
#
# Hook, S. TIS zn Herb Caen 1963
#
# · ..
#
# folder
#
# I
#
# drafts (t.) with holo. corr. to reviewers, of B. statements to
#
# Encounter M3.ga.zine re Hook.
#
# Research notes and material for background writing -
#
# clips, memeos etc.
#
# t. c. of memo by Harvey Wheeler of dinner discussion with
#
# Edward Teller and Burdick at dinner. 13 /. in which extended
#
# quotes of Teller's political philosophy are given and the writers
#
# interpretation of these statements.
#
# folder j Burdick - Wheeler corr. 1961 - 62
#
# folder
#
# also many other letters incl., serial and !!_ pub. rights
#
# copies of contract, ptib. releases, foreign contract
#
# corr. from Houghton
#
# t.c. of' letters from B to W.
#
# TIS Wheeller to EB (several)
#
# Clippings of' reviews, copy of dust jacket, BOMC News.
#
# xerox copies of' letters or statements by Isidor I Rabi)
#
# Linus Pauling, itc •
#
# Ba)(· ·folder ✓ M:>'S'ie clips ( Columbia Pictures)
# >i)
#
# folder ✓ "Red Alert" 1962 - 64
#
# Wheeler, Harvey AIB · encl. t. c. of background statement..J ie for
#
# preface.
#
# coIT. re. similarity with "Red Alert"
#
# Wheeler, H TIS May 12 and other from him all concerned With
#
# legal action over the plagarism charge.
#
# folder J Saturday Review 1963
# "The Politics of Destruction" article in S R Hov.9, 1963 by
#
# E B and Wheeler.
#
# Wheeler, H TIS Jun 25, 1963
#
# and t.c. of article with earlier title "Fail Safe and Nuclear Politics"
#
#
#
# Boxes 40-46
#
# folder ✓ M:>vies 1963
#
# Wheeler, H. TIS July 29
#
# incl. draft for TV show and contract
#
# folder /~creenplay Mimeo c. of text by Wa.:Her Bernstein
#
# 2d dra.:rt March 15, 1963 some holo. corr.
#
# folder v·Fra.nkennuth High School 1964
# ~·-;1;e_--.. _
#
# Play based on nove}(J>y David Sim~ mimeo c.
#
# for corr. re this see next folder.
#
# Box. 4 ~ler v Fan Mail (incl. xerox copies of ones to Wheeler)
# ./ Salisbury, Harrison TIS 1962 xerox
#
# ✓ Wylie, J C TIS 1962 AIS(Postal) (admiral)
#
# ~ xx Wylie, Philip TIB Florida, 1962 3 p. author
# excellent letter
#
# Berkeley, J P AIS [1962] general
#
# v Mitford, Jeesd.ca TIS Nov. 6, 1962
#
# :xx Walter, Robert H. K. Oct 19 n,~ author
#
# folder ✓ Notes, drafts, etc.
#
# incl. proof" of Sat. Rev. article {see folder above)
#
# also TV drafts, chapts from H W etc.
#
# folder ✓ :Ba.ckground t.c. copies of' draft statement
#
# folder / S A C Bomber Story several t. copies fhapt ~
# folder ✓ Introduction 1 draft M3.y, 1962, l undated t. c.
#
# Box~~
# . -f6lder The Conference Line t. c • variant draft.
# 13.ax.J.1'3-~1, ✓,-3 Box~
# 23 folders Chapt 1 - 23 "'.J.(- 8'" .Bo>( ~o/
#
# liq - '1 Box 4~
#
# v,o-- ~ 3
#
# various dated dra.fts, t. and xerox copies up to chapt.
#
# has only l t. c.
#
# First proofs 1962
#
# BoxL/l,
#
# 21 - 23 which (,e, J3)
#
# incl. printert s copy of typescript {pril. j. in t. tex:j in
#
# thermofa.x copy) B46 _2.
#
# folder Galleys. dated Aug. 14, 1962.
#
#
#
# '
# Boxes 47-49
#
# · ...
#
# Burdick, Eugene addenda Oct '66
#
# manuscripts
#
# AMERICAN VOTING BEHAVIOR edited by EB and Arthur J. Brodbeck
#
# 22 folders by chapter typescript, halo. corr. and printer's marks
#
# galley prints - first and second copies
#
# "The Lonely American" filmed series by EB and Turnley Walker
# !J
#
# 4 carbons 269].
#
# SYNDICALISM AND INDUSTRIAL UNIONJJ3M IN ENGIAND UNTIL 1918
#
# by EB, Mlgd.a.len College, Oxford 1950 thesis four volumes 2 copies
#
# carbon with some halo. corr. 555,. . each.
# ·,
#
# correspondence
#
# Boxes 50-55 folder I Kamina Inc. publishers correspondence covering 1963 - 64
#
# including:
#
# Knowlton, Perry H. TIS 1964, Sept . 8.
#
# Gang, M:Lrtin 10 TIS 1963 and 65
#
# Lederer, William 1 t. c. signed 1965 M3.y 28
#
# Lederer, William 1 mimeo contract signed 1964, Aug 17.
#
# folder II ~artin Gang correspondence
#
# including 1964 - 65
#
# Gang, M:trtin 4 TIS 1964
#
# Wells, Ml.rk 2 AIS 1964
#
# folder· III correspondence Jan - May 1964
#
# Walter, Paul W. TIS 1964 Mty 25
#
# Brown, Dyke TIS 1964 M:Ly 22
#
# Rosten, I.eo AIS 1964 M9.y 18
#
# Brodbeck, Arthur AIS 1964 :M:t.y 2
#
# Battin, Robert W. TIS 1964 April 27
#
# Nolte, Richard H. TIS 1964 April 22
#
# Daly, Thomas A. TIS 1964 April 8
#
#
#
# Boxes 50-55 Butts, Charles TIS 1964 M:l.rch 3
#
# O'Connell, James B. TIS 1964 April 6
#
# lee, Roger AIB 1964 April 5
#
# Brown, Francis c. TIS 1964 M:Lrch 11
#
# Hoffer, Eric AIS 1964 Feb 20
#
# Rossitto, Guy (Dr.) TIS 1964 M3.rch 3
#
# Belli, .tvElvin M. TIS 1964 Jan 29
#
# Untermeyer, Louis TIS 1964 Feb 4
#
# Post, Landon D. TIB 1964 Feb 13
#
# KBohn, Peter L. TIS 1964 Feb 25
#
# Hall, "Bob" 2 ALS 1964 Jan 31
#
# Higman, Howard TIS 1964 Jan 22
#
# Thomas, "Bob" TIS 1964 Jan 14
#
# M::>rga.n, Neil TIS 1964 Jan 17
#
# Aceland, Charles (Capt. ) AIS 1963 Dec.
#
# levy, Dr. Harvey AIB 1963 Dec 9
#
# Hutchins, Robert M. TIS 1963 Dec 27
#
# correspondence Jan - June 1965
#
# Emery, Ella AUJ 196 5 April 19
#
# Blumberg, Nathan AI.S 1965 .May 21
#
# Burnett, Robert AIS
#
# Droz, Clement TIS 1965 April 21
#
# Barrio, Raymond 1 TL, 1 TIS 1965 M:Ly 3, 1965 M3.y 7
#
# Sherlock, John TIS 1965 :tvay 11
#
# Price, Joe D. C~hiti Joe? AIS 1965
#
# Vol tchenko, N. Mne, TIS 1965 .May 10
#
# Scalopino, Robert A.
#
# I.edner, Caryl TIS 1965 M3.y 10
#
# Nimmo, R. H. ( Gen. ) TIS 1965 April 22 (West Pakistan)
#
#
#
# Boxes 50-55 · ~rdingev, C. J. (capt. ) TIS 1965 April 1
#
# Stanley, David G. TIS 1965 April 15
#
# Hutchins, Robert M, TIS 1965 M3.rch 26
#
# Shaffren, M:Lry Ann TIS 1965 M:l.rch 22
#
# Radford, Alf' TIS 1965 M:trch 17
#
# Watson, Graham TIS 1965 ~rch 10
#
# Sundra, Triska TIS 1965 M:l.rch 20
#
# Walker, Turnley TIS 1965 Feb 27
#
# Wheeler, Dr. Harvey TIS
#
# Kaiser, Henry J. (Mrs.) TIS 1965 M3.rch 5
#
# Edington, Donald TIS 1965 M3.rch 4
#
# Johnson, Nunnally TIB 1965 Feb 21
#
# .M3keba, Miriam TIS 1965 Feb 10
# Belafonte, Harry
#
# Allen, James S • TIS 1964 Dec 5
#
# McEvedy, Colin TIS 1965 ¥.arch 3
#
# Hoffman, Hallock TIS 1965 Jan 21
#
# Garner, Lois AIS 1965 Jan 13
#
# *Farolan, Modesto ( Phillippine ambassador to ¢if/xftfl Switzerland
#
# - formerly Saigon) TIS 1965 Dec 8
#
# Miller, James TIS 1965 Feb 1
#
# McCarthy, Paul TIS 1965 Feb 4
#
# M:thler, Capt. George TIS 1965 Jan 27
#
# Wood, Hugh II 2 AI.B 1965
#
# I.arson, Arthur l TIS 1965 Jan 22
#
# Kronhausen, Phyl & Elie 1 TL ( holo. ps) 1965 Jan 23
#
# Ulman, Lloyd TIS 1965 Jan 11
#
# Stenger, Alfred TIS 1964 Dec 12
#
# Rad:f'ord, A. S. TIS 1964 Nov 2
#
# Wells, John A. TLS 1964 Dec 8
#
# Watson, Graham TIS 1964 Dec 15
#
#
#
# Boxes 50-55
#
# ' ..
#
# Rischin, M,ses TIS 1965 Jan 4
#
# Nimmo, Gen. R. H. AI.S 1964 Dec 14
#
# folder "N General correspondence June - Dec 1964 including:
#
# M:J.y, Car 1 V. 2 TIB 1964 Dec 3, 1964 Nov 24
#
# Jonas, Allan K 1 TIS {holo. p.s.)
#
# Ford, Anne 1 TIS 1964 Nov 23
#
# Wada, Tsutomu 1 TIS 1964 Nov 25 {Consul Gen. of Japan)
#
# Treuhoft, Jessica TIS 1964 Nov 8
#
# Spock, Benjamin M.D. TIS 1964 Oct 16
#
# Jackson, William AIB
#
# Cohen, Arthur TIS 1964 Oct 29
#
# Price, Joe D. ("Tahiti Joe")TIB 1964
#
# Kuhn, Ecl.ward TIS 1964 Nov 19
#
# Cawthorne, Sir Terence TIS 1964 Oct 30
#
# Kaiser, Edgar F 1 TIB 1964 Oct 6
#
# Don M:>desto, Camparado 1 TIS 1964 Sept 2
#
# Belli, Melvin M. TIS 1964 Oct 7
#
# Humphrey, Hubert H. TIS 1964 Oct 5
#
# Gicas, Nicholas P TIS 1964 Sept 7
#
# Zack, Arnold TIS 1964 Sept 22
#
# Bayh, Senator Birch TIS 1964Aug 7
#
# Brodbeck, A. J. (Dr.) TL 1964 Aug 19
#
# Hilton, Mtry Alice TIS 1964 Sept 18
#
# Perlmutter, Jerome H. TIS 1964 July 22
#
# Bradford, G. L. TIS 1964 Aug 4
#
# ffawcett, Roger TIS 1964 July 10
#
# Shukla, Cb.avan Vidya TIS 1964 June 25
#
# Brockway, George P. AIS 1964 June 30
#
# Maxim, Iarry T. TIS 1964 June 3
#
# Goldman, Eric F. TIS 1964 May 4 (Advisor to Pres.)
#
#
#
# Boxes 50-55 folder# 1 labelled 11Telsun Company" contains material written
#
# by EB's students for political science 201a fall semester 1957
#
# f'older # 2 labelled "Presidential • 64" COQ.tains printed material
#
# relating to the 1964 election year.
#
# f'older # 3 labelled "Communist Book Off'ens i ve A J release, Dec 1960 11
#
# contains printed material, mostly foreign periodical publications
#
# and US I A pub. plus l TIB from Albert J. Lubin (USIA) 1960, Aug 8.
#
# folder # 4 labelled "Poli tics, 1960 Pres. Election - Democratic
#
# campaign material" includes sections containing:
#
# 1. Stevenson-Kefauver Fina.nee Committee material - fall 1956
#
# 2. printed amd mimeo. material relating to 1956 elections ie;
#
# a. "The Political Profile of the American Electorate"
#
# by Warren E. Miller, labelled "not for public release"
#
# b. "The Pe.ttern of Governor Stevenson• s Speeches" analysis
#
# and recommendations.
#
# c. etc.
#
# 3 • printed and mimeo. material relating to 1960 presidential
#
# election ie;
#
# a. "Facts" for victory in '60 published b fl Democratic
#
# National Committee Research Conunittee. 6 issues.
#
# b. Biographical and related material on JF Kennedy and LB
#
# Johnson.
#
# 4. material labeled "Campaigns, Personal" includes letters
#
# (carbon) from EB to other members of the Academic Profession
#
# to support Adlai Stevenson for President, ie; first draft
#
# typescript of letter to Arthur Schlesinger, Jr., Stevenson
#
# Campaign Headquarters, Springfield, Illinois
#
# 5. campaign pamphlets and posters.
#
#
#
# Boxes 50-55
#
# Burdick, Eugene
#
# I. Printed l-13.terial
#
# Australian Profile
#
# 64 Assorted pamphlets, souvenir books, maps, c<hrcularsf etc.
#
# US NAVY war plftotographs printed book
#
# Xerox bibliographies of navigational books
#
# Newspaper article "Colored boys banned" Daily Mirror 11/20/62
#
# fb_otographs from Dept. of National DevelopIIEnt 6/29/62
#
# Newspaper article "Strange Gift ,of Robert Hughess" 8/19/62
#
# Legislative AssemblW notices of motions and orders of the day-Oct. 9-11
#
# 1956; Oct. 16; april 3, 1962
#
# Galley-Illegitimate Power
#
# Tour of ,Duty
#
# Uncorrec~ed Galley Proofs of Government by the People by Burns and
#
# Pellason Parts 1,2,3
#
# Uncorrected proofs of 'IHAT PELIET WOMl\.N by Betty Pellet
#
# Uncorrected proofs of Government By the People -Part 4
#
# Letter:
#
# Barrett, Peter TIS 6/29/62 1 j) .
#
# Weil, Doris, AIS 7 /21/62 11.
# Rubbo, .Michael D. 1'lB 8/7/62 1 J .
#
# Killion, J.J. TIS 6/21/62
#
# Nelson, David TIS with carbon copy 5/25/62 lJ ..
#
# Levintahl, Sonia TIS 7/10/62
#
# Gabriel, Jack TL-carbon copy from EB
#
# Ryon, WDSON TIS 8/25/61
#
# Typed essay-no title or date 4} .
#
#
#
# Box 56
#
# ·,.
#
# folder# 1 labelled ''Psych Process & President" contains:
#
# a. "Psychological Processes and Political Institutions" by EB
#
# rough draft, typescript with holo. corr. 27 .f.
#
# b. "Psychological Process and Political Institutions: A Preliminary
#
# Theory for the Inquiry" by EB
#
# typescript with holo. notations (3 f. ), 28 /
# carbon typescript with conclusion 29/.
#
# c. related correspondence including:
#
# 1. Herz0g, Elizabeth TIB 1958 May 14
#
# 2. Riiten, Prof'. Dr. AJC 2 TIS 1955 Sept 12, 1955 Dec 8
#
# 3. Mcclosky, Prof. Herbert 1 TLS 1958 April 16
#
# 4. Ross, Helen AIB
#
# d. misc. holo.j. (12) notes for text, footnotes, and bibliography
#
# folder# 2 labelled "Day of the Mutiny" contains "Day of the Mutiny"
#
# ' typescript with holo. corr. 28)..
# folder# 3 labelled "San Francisco Article, Holiday 4/61" contains"
#
# a. "San Francisco" typescript (holo. note "early draft") 25 /.
#
# b. carbon typescript with typed corr. 2 copies 28 /. each
#
# c. printed and typed background material relating to the San
#
# Francisco article.
#
# folder# 4 labelled "Mexican Article 1' Holiday M:tg. contains:
#
# a. "MeJEico" by EB typescript with holo. corr. 27 /.
#
# b . "Mexico" by EB
#
# 1. carbon typescript with holo. corr. 33/.
# 2. carbon typescript 3 copies 29/.
# 3 • carbon typescript 30 /.
#
# c. "Mexico" typescript with holo. corr. 17 /.
#
# d. notes - typescript with holo. corr. 13 J. plus 2 carbons
#
#
#
# Box 57 e. llotes,'typescript - With holo. co=. 1 J .
# f. printed material, photographs, and other background irrfo. for
#
# article.
#
# g. correspondence for '1Mexico" article · 18 TIS to EB from Holiday
#
# Mag. and various Mexican tourist bureaus, 24 carbons of EB
#
# letters. 1962 April - Nov.
#
# folder # 5 labelled "Washington Story" Holiday M3.g. contains:
#
# a. 11Washington, D. C. :Two Realities, Two Shadows" typed carbon
#
# with hoo. corr. 11f.
# b. correspondence
#
# Scions, Harry telegram 2 /. 1962 Jan 3
#
# Scions, Harry TI8 2 f. 1961 Oct 27
# folder# 6 labelled "Holiday Proposal, Southeast Asia - Burdick-
#
# Englund II contains :
#
# correspondence
#
# 1. Englund, George AIS n.d. attached is a carbon of a letter
#
# written by Englund to General Chalermchia dated 1961 Sept 19.
#
# 2. Burdick, E. TIS 4 /. to Sions n. d. plus 2 carbons
#
# 3. Burdick, E. 4 typed carbons of letter (3 J_ . )to Sions
# dated 1961 Nov 6
#
# folder # 7 labelled 1'Hong Kong" Holiday contains:
#
# a. "Hong Kong" by EB typescript with holo. corr. 27}. plus 19/.
# of typed corr.
#
# b. r!Hong Kong" typescript •with holo. corr. 16 / plus carbon and
#
# 7 f. of page corr.
# c. printed material on Hong Kong
#
# folder # 8 labelled "The World of the Pacific·~ Holiday 1960 contains:
#
# a. Brook, Paul. TIS 1959 Dec 31
#
# b . 2 carbons of letters by EB
#
#
#
# Box 57 folder #= 9 labelled 11South Pacific" holiday mag.
#
# correspondence:
#
# Aucker, D. H. TIS 1960 Oct 13 (High Commissioner Trust
#
# Territories of the Pacific Islands)
#
# fold.er#= 10 labelled "Perfect South Sea Island" Holiday :Mtg.
#
# tear sheets of artic.:e
#
# folders#ll - 14 labelled "Voting Continuity Volume" 1955 - 56
#
# a. (# 11) correspondence 1955 42 TIS to EB 78 carbons by EB
#
# Riesman, David 2 TIB 1955 Aug 27 and June 25
#
# Bradbeck, Arthur J. (Asst. Prof. in Psych. Boston University)
#
# 9 TIB, 1 TL, 1955 Aug 19 - April 4 1957
#
# 10 t. c. of AJB's letters.
#
# b. (# 12) Voting Continuities Volume correspondence 1956
#
# 47 ms to EB 64 typed carbons of EB letters
#
# Allport, IJ.oyd H. AIS (2j.) 1956 Sept 8
#
# Parsons, Talcott ( Chairman Dept. of Social Relations Harvard U. )
#
# 1 TIS 1956 Sept 17
#
# Brodbeck, Arthur J. 14 TIS, 8 TL, 1 AIS 2 telegrams
#
# (34 / in all) 1956 Jan 11 - Aug 14 2 not dated.
#
# c. (#= 13) labelled Voting Continuities Correspon/dence fall 1956
#
# 89 TIS, 3 AIB, 103 carbon replies
#
# Brodbeck, Arthur J. 37 TIE 1956 Aug 31, -1957 Jan 1
#
# Riesma.n, David TIS 1956 Aug 31
#
# · Kluckhobp) Clyde TIB 1956 Aug 27
#
# Berelson, Bernard 4 TIS 1956 June 7, May 9, 18, 28.
#
# Rossi, Peter H. 1 TLS 1957 Oct 1
#
# Wahl, CW TIS 1957 April 9
#
# Lazaasfeld, Paul F. 5 TIS 1956 M3.y 7, June 5, Sept 211957 April
#
# 5, Oct 29.
#
#
#
# Box 57
#
# Box 58
#
# Parsons, Talcott ~ TIS 1956 Oct 2, TL 1956 June 12.
#
# articles including the following:
#
# 1. Introduction by EB and Brad.beck typescript 4,{.
# 2. Introduction typed carbon 3 j.
# 3 • A J Brodbeck article
#
# a. "The Principles of Permtlnence and Change: Electioneering
#
# and Psychotherapy Compared" typed carbon with
#
# halo. corr. labelled rough draft 23 ~ •
# b. same title, carbon typescript labelled next to last chapt
#
# (Am voting Behavior) 36 /
#
# c. same title, typescript labelled rough draft 6 /.
#
# 4. chapt. I mimeo. with halo. corr. 69 /.
#
# 5. Rossi, :Peter article "Four Landmarks in the History of
#
# Research on Voting"
#
# a. above title carbon typescript 68 /
#
# b. outline of above typescript with halo. corr. 7/.
# c. mimeo. of article 2 copies
#
# correspondence re AMERICAN ~OTING BEHAVIOR 1958 - 59
#
# mostly business correspondence
#
# Brodbeck, Arthur J. 6 TIS 1958 Dec 4, 8, 29, 1959 April 16, 2 n.d.
#
# Roshwold, Irving TIB (Director of Research Gallup and Robbinson,
#
# Inc.) 1958 Dec 31.
#
# d. (# 14) ''Voting - Critique of Iazat?sfeld Book" contains:
#
# material of a background and organizational nature for
#
# the Voting Continuity \61.ume with a mimeo. format of book,
#
# chapter outlines (carbon)
#
# folder# 15 labelled Gen. Correspondence 1957 - 59 113 TIS, 127 carbons
#
# of EB - mostly business and fan mail
#
# Coblentz, William K. (Sec. to Gov. of California) TIS Feb 18, '59
#
# Stout, Rex TIS (2 f.) 1959 Feb 2
#
#
#
# Box 58
#
# ...
#
# Box 59
#
# Bradema.s, John ( Congressman) TIS 2_(. 1959 Feb 18
#
# Thompson, Kenneth W. TIS 1958 Dec 2, 31, 29, 15, 1954 Feb 27.
#
# Muste, A. J. (Editor of "Liberation" British monthly) TIS
#
# Dionisio, Jaun C ( Phillippine Author) TIS 1958 Oct 27 plus
#
# carbon of chapt. III of his book ACCIDENT
#
# Brown, Dyke (Vice Pres. Ford Foundation) TIS 1957 Dec 4
#
# Hill, Herbert (Labor Sec. NAACD) TIS 1957 Oct 9
#
# I.eenard, J. Paul (Pres. of Am. University of Beirut) TIS
#
# 1957, Oct 20
#
# folder # 16 labelled 0Voting Reference" contains charts, outlines,
#
# and bibliographies on certain aspects of voting statistics
#
# folder # 17 labelled "Business Reference" contains bibl.iography and
#
# summary outline on business trends etc.
#
# folder # 18 labelled "Voting .Material" re book AM. VOTING BEHAVIOR:
#
# CONTINUITmS IN T'.rlE VOTING STUDmS
#
# a. contains printed and ty:ped material re book content plus the
#
# following correspondence
#
# l. Campbell, Angus 2 TIS 1957 Jan 25, 28
#
# 2. Parsons, Talcott 2 TIS 1956 Dec 20, 1957 Jan 23
#
# 3. Ellison, Richard TIS 21. 1961 April 21
# 4. Brodbeck, Arthur J. 4 TL n.d.
#
# b . "Political IJ:heory and Voting Studies" by EB typed carbon 25 .
#
# folder # 19 labelled "American Voting Behavior '.
#
# a. printed and typed material, book format outlines and poll graphs
#
# b. correspondence
#
# 1. Modigliani, Franco TIS 1958 April 22
#
# 2. Rermnens, H. H. 2 TIS 1956 Jan 26, and 1958 April 14
#
# 3. Parsons, Talcott TLS 1956 Oct 18
#
# 4. Riecken, Henry W. TIB 1956 Mar l
#
#
#
# Box 59
#
# Box 60
#
# \
#
# 5. Campbell, Angus TIS 1956 Nov. l3
#
# 6. Roshwalb, Irving TIS 1956 Feb 14
#
# 7. Brodbeck, Arthur J. TIS 1956 April 11
#
# .folder # 20 labelled "Voting Behavior Notes n printed correspondence
#
# and typed material re voting behavior
#
# folder# 21 labelled copies of articles for AM. VOTING BEHAVIOR
#
# mss . and carbons of the following articles:
#
# 1. Introduction by EB and .AJB typescript with printer's
#
# marks 3 f. plus carbon of same
# 2. Chapt 22 "The Principles of PermQP.ence and Change:
#
# Electioneering and Psychotherapy Compared" typescript
#
# with printer's marks and end notes 39/. plus carbon
# with printer's marks and page of changes 4o f.
#
# 3. Chapt. 15 "Social Determinism and Electoral Decision:
#
# The case of Indiana If by V. O. Key, Jr. and Frank Munger
#
# a. typescript with printers' marks and end note 31.(.
# plus 2 carbons
#
# b. final draft typed carbon
#
# V.O.Key, Jr. 1956 Jan 27
#
# with TIS from
#
# 4. Cha pt. # 16 "Emotional Factors in Voting .Behavior" by
#
# Franz Alexander M.D.
#
# typescript with printer's marks and notes J3/. plus
# 3 carbons J3/. each
#
# 5_.. Cha pt. # 17 '' Independents and Party Identifiers: Characteristics
#
# and Behavior in 1952" by Robt. E. Agger
#
# 1. carbon typescript with printer's marks and end notes
#
# 45/
# 2. ty~script 45 /.
#
# 3 • carbon typescript 38 j.
#
#
#
# Box 60 6. Chapt. # 18 rr.Analyzing the Social Process Underlying
#
# Group Voting Patterns" by R. Duncan Luce
#
# a. tniescript with holo. corr. and printer's marks 31/.
# b. carbon tniescript 35),
#
# 7. Chapt # 19 "Partisan Attitudes and the Pres identia.l
#
# Vote" by Angus Campbell and Donald E. Stokes
#
# a. mimeo . with holo. corr. and printer' s marks 3 if_ .
# b • carbon ty:pescript 31 / plus 3 /. of changes
#
# 8. Cha.pt# 20 "Some Recent Developments in the Use o:f Panel
#
# and other Survey Techniques in Economic Analysis and
#
# Forecasting" by Franco Modigliani and J. E. Bolderston
#
# a. mimeo. with printer's marks 2 copies ea.ch 36J.
# plus carbon TIS BoldersEn J.E. 19 56 M:Lrch 5 1
#
# b. mimeo. with some holo. notations 3 copies ea.ch 24 .
#
# c. tniescript 33/.
# d. carbon typescript 40 /.
#
# 9. Cha.pt. 21 "Some Psychodyna.mics Aspects o:f Voting Behavior"
#
# by Richard E. Renneker M~D.
#
# a. i;Jipescript 17 /
#
# b • tnied carbon with printet s marks 17,(.
#
# c. tnied carbon 21/.
#
# 10. Cha.pt 22 "The Psychology of' Social Motivation and Social
#
# Learning in the Voting Studies" by Arthur J. Bre.dbeck
#
# carbon tniescript 2 copies each 19/.
# "About the Contributors" tnied carbon . 3 {
#
# listing author credits
#
# Table of Contents of' Books mimeo. 6 copies
#
# Table o:f Contencts of Essays in Voting Behavior mimeo.
#
# 1 COPJ[ 7 f.
# Skeletonized f'ormat of Voting Continuity Volume mimeo.
#
# 6 copies
#
#
#
# Box 59
#
# Box 61
#
# folder # 22 Ia.belled "Fan Filing" carbons of EB' s letters ( 8)
#
# 13 J.. plus tear sheets from House Beautiful, article describes
# an example of Eastern Architecture in the West.
#
# folder # 23 labelled 11A J\bdest Proposal 11 ~orrespondence
#
# Weidner, Edward W. TIS 21. 1965 M3.r 25.
#
# manuscript "A Modest Proposal" by EB typescript with holo. corr. 5j.
# folder I 24 labelled "Carlos Garcia - Palacios"
#
# 2 copies of M3.rlon Brando sketch, ty:pescript and carbon, l::oth signed
#
# by CGP
#
# TIS from CGP to EB 2 / 1961 Jan 30
#
# Draft of letter from EB to Frank Stanton (Pres. of CBS) with hole.
#
# corr. written from Pago Pa.go, Am. Samoa
#
# folder # 25 (blue) contains clippings, correspondence, etc. re his
#
# student days at Oxford
#
# 1. Hailey, Foster (European Correa. NY Times) 3 TIS 1949, Nov 2, Oct
#
# 17, 28
#
# 2. Barrett, Covelli D. 2 TIB 1949 Oct 24, Nov l
#
# 3. Teasheets of "Burdick with a .Baedeker" The Isis 1949 Oct 12
#
# 4. manuscripts (2) untitled but dealing with Oxford typescripts 22/..
#
# folder # 26 labelled "Perceptions, Inc" contains 154 TIB, 12 AIS, 170
#
# carbons 1957 - 58
#
# 1. Iasswell, Harold D. TIS with holo. note 1958 May 12
#
# 2. Winters; Yvon copy of' TL 1957 Oct 17
#
# 3 . Lederer, William J. TIS 1958 Oct 16
#
# 4. Conell, William (Ad.min. Asst. to Sen. Hubert Humphery) TIB
#
# 1964 July 22
#
# folder #27 labelled "McGraw Hill" business cnrrespondence 1957 - 1964
#
# 65 TIS from McGraw Hill, 72 carbons from EB
#
# folder # 28 labelled "The Democratic Party" Holiday M3.g. June 1960
#
# typescript with 3 carbons 37 J. each
#
#
#
# Box 61
#
# Box,62
# ·,
#
# folder # 29 labelled "Am. Voting Behavior Correspondence"
#
# 1. Alexander, Franz M.D. 2 TIS 1958 June 4, Feb 20
#
# 2. Roshwald, Irving TIS 2 /. 1958 April 3
#
# 3. Iazarsfeld, Paul F. TIS 1958 M:J.y 7
#
# 4. Brodbeck, A. J. 11 TIS 1 AIS 6 not dated
#
# 1958 July 30, Jan 19, Nov 4, April 4, 11, 22
#
# folder# 30 labelled "Correspondence July - Dec 1965"
#
# 1. Smith, Geoffrey Johnson M.D. TIS 1965 July 5
#
# 2. Kucher,, Thomas H, (U.S. Senator) TIB 1965 June 9
#
# 3 • Sutton, Horace (Sat. Rev. ) TIB 1965 April 14
#
# folder# 31 labelled "Where Do you want this??" misc. corr.
#
# l. Burdick, EB TIS 1964 May 22
#
# 2. Hoffman, Hallock TIS 2 /.. 1961 M:t.rch 16
#
# 3. Schlesinger, Arthur Jr. TIS 1961 M:1.r. 14
#
# 4. Haddad, William (Special Asst. Peace Corp) TIS 1961 April 19
#
# 5. Shriver, Robt. Sargent, Jr. TIB 1961 Apri~ 2
#
# 6. Schlesinger, Arthur Jr. TIS 1958 Nov 18
#
# folder# 32 labelled "General Correspondence 1962"
#
# 41 TIS, 57 carbons by EB, 2 tiegra.ms, 2 AI.13
#
# 1. Salisbury, Rachel (Dr.) TIS 1962 Dec 2
#
# 2. Chapman, Carleton B (MD) TIS 1962 Oct 19
#
# 3. Parsons, Michael J. TIS 1962 Sept 4
#
# 4. Stanton, Frank TIS 1962 Aug 27
#
# 5. Bradbury, Walter J. TIS re SEVEN DAY$ IN MAY plus
# -,
#
# by EB 1962 ~y 7
#
# 6. Walter, Robt. H.K. 1962 May 4
#
# 7. Friednan, JG (Univ. of Munich) TIS 1962 Mar 26
#
# carbon reply
#
# folder # 33 labelled "General Correspondence" 1960 43 TIB, 67 carbons
#
# by EB
#
# Lincoln, Evelyn (Sec. to Pres. Kennedy) TIS 1961 Nov 30
#
#
#
# Box 62
#
# Box 63
#
# folder# 34 small envelope containing news clippings of reviews
#
# of 480 novel by EB 1964
#
# lectures, articles, and course material
#
# • folder # 1 labelled "Herald Tribune Travel ,Guide 'Island Smells"
# 1. "The Neglected Perception" ( later changed to "Island Smells")
#
# typescript vith halo. corr. 51,.
# 2. carbon typescript of same 4J.
# 3. Iescherer, Barnett D. - Travel Editor of NY Tines TIS 1963 Dec 19
#
# plus 2 carbons TL by EB and telegram
#
# 4. tear sheet of article plus note TIS from Iaaherer.
#
# folder # 2 labelled "The Invisible Aborigine" business correspondence
#
# with Harpers M3.g. and misc. fan mail Sept 13, 1961 - Mlr 14, 1962.
#
# Plus a short biographical sketch of EB typescript 3 carbons each 1/.
#
# folder # 3 labelled "Idyll in the Southern Solomons, Sept 1956"
#
# outline oJ article typed carbon 2 copies each 6 ).
# typescript of article 20 /.
#
# misc. correspondence re the article, business, fan, and carbon replies
#
# folder # 4 labelled "Indonesian Article" 1962
#
# 1. notes for article typescript with some carbon and photo (. 61 f
# 2. "Indonesia - Giant of the New Politics" by EB and Wm Iederer typed
#
# carbon 15.J.
#
# 3. 'Tae Forgotten Poverty" by EB and Wm. Iederer 6 /. photocopy
#
# 4. News clippings photo copy of letter from Robertson, Walter 8.
#
# (Asst. Sec. of State) 1958 Nov 22
#
# 5. rough draft of article typed carbon with holo. corr.
#
# plus rough draft insert typed carbon 2 /.
#
# 6. typescript with profuse bolo. corr. 30/.
#
# 7. correspondence (business) some printed material
#
# folder # 5 labelled "The Nation - calif. Riitical Article"
#
# McWilliams, Carey 6 TIB 1959 Oct 4, 1958 June 23, plus carbons of EB's
#
#
#
# Box 63 folder # 6 labelled "N Y Times Articles"
#
# 1. xerox copies ( 2) of article "The Pa.per Back Book" 2 l. each
# 2. clipping of articles
#
# a. "Trailing a Curious Political Animal" 2 copies NY T M:Lg.
#
# Ma.y]3, 1964
#
# b. "The Pap er Back Book" column entitled "Author's Like
#
# Them Too" NYT 1965 Jan 10
#
# folder # 7 labelled "N Y Time Article - Calif. Pol. Piece"
#
# 1. notes typescript with hole. corr. 5 )·
#
# 2. "A Proposal for an Article on Ga.lifornia Politics, Nov 1958"
#
# typescript 51
# 3. correspondence Stewart, John G. N Y Times Sunday 1958 July 11,
#
# 1958 Nov 5 2 TIS plus carbon of EB's replies
#
# folder# 8 labelled "NY T Sunday Mag. - California"
#
# 1. typescript with some carbon . and hole. corr. 16 /
#
# 2. correspondence Bergman, lewis (Exec. Ed. NY Times .Mtg.) TIS
#
# Dec 26, 1962
#
# Fox, J. M (Ed. Random House) TIB 1962 Dec 5
#
# folder # 9 labelled "New Republic M:l.g. Corresp. ff
#
# Harrison, Gilbert A. (Ed. and Pub.) 3 TIS 1956 M3.y 24, Oct 23, Dec 13
#
# plus carbons of EB's replies
#
# folder# 10 labelled "The Perfect President"
#
# 1. poem by Clarence E . Hoop hole. "The American Prayer ff ( the
#
# Psalm of Life)
#
# 2. "The Personality of the President" typed carbon with halo.
#
# corr.
#
# 3. correspondence misc. business and fan mail
#
# a. Scrivner, Evrett P. {Congressman) 2 TIS 1956 Jan 6, 11
#
# b. Hughes, Thomas L. {Senator) TIS 1956 Jan 11
#
# c. carbons of EB's replies
#
#
#
# Box 63 4. tear sheets of article "The Perfect President" This Week
#
# Jan 11956
#
# folder # 11 labelled "Perino Article" Holiday
#
# 1. 3 menus from Perinos Restaurant 1958 June 5(Thus 2 copies), July 28
#
# (M:mday)
#
# 2. carbon typescript Sept 6 draft 18 J
# 3. carbon typescript final draft 20}.
#
# 4. typescript with holo. corr. revision
#
# 2 copies
#
# (2 copies)
#
# 1a(
# 5. autobiographical sketches of several Perino employees
#
# 6. correspondence business and fan
#
# folder # 12 labelled "Promotion File 1955 - 56" re job promotion at
#
# Berkeley
#
# 1. Kerr, Clark AIB 1956 July 27
#
# 2. Aiken, Charles TIS 2 J 1956 July 16
# 3. Burdick, E. ty:ped carbon of letter sent to Peter Odegard
#
# stating qualifications for promotion request 3 f. (plus 2 carbons)
# 1955 Oct 19
#
# folder# 13 labelled "Regents Profess6:tts Cite on - " correspondence 1955
#
# Odegard, Peter 2 TIB 1955 Dec 19, Nov 14
#
# folder# 14 labelled "Rockeffeller Grant, fall, 1958" contains a
#
# meorandum from E W Strong signed with mimeo. announcement to grantees
#
# folder# 15 labelled "Rockefeller Grant (Theory) 1956"
#
# 1. carbon typescript of "Proposed instructions from the Chancellor
#
# to the Committee that Will disburse the Rockefeller Grant"
#
# 2 copies each a 1
# 2. draft on "Evolution and Other Problems" of Rockefeller Grant
#
# by EB typescript with holo. corr. 2/. (plus carbon)
#
# 3. other typed materials relating to Rockefeller Grant
#
#
#
# Box 63
#
# Boxes 63-64
#
# Box 65-
#
# e.
# folder # 16 labelled "Retire~t" material relating to retirement
#
# insurance
#
# folder # 17 - 39 Class room material, some lecture notes, student
#
# papers, grades, remarks, and criticisms by EB
#
# folder If 40 labelled "Speech" Col IA 1957 "The Faces in the University
#
# Crowd" typescript with halo. corr. 6 j.
# folder # 41 labelled "Television Committee, '55-56"
#
# misc. correspondence and mimeo. material
#
# folder # 42 labelled "Travel" U. of Cal. at Berkeley expense acct.
#
# vouchers 1953
#
# folder # 43 labelled "University Welfare Cut , fall 1956" printed
#
# and mimeo. material
#
# folder # 44 labelled "Student Advisees" printed and mimeo, and
# 1 •
#
# xerox material from DeansOffice
#
# folder# 45 labelled "Language Project" contains typed carbon
#
# statement of purpose 5 .,(.
#
# folder # 46 labelled "p. S. Committee on lecture Series II material
#
# tpped and carbon relating to organization of Berkeley lecture
#
# Series plus following correspondence
#
# 1. Odegard, Peter H. TIS 1953 Oct 14
#
# 2. Scalapino, Robert A. TIS 1953 Oct 2
#
# 3. Carbons of EB's replies etc.
#
# folder# 47 labelled "Political Science Convention, 1956 (Panel Papers)"
#
# mimeos. of papers presented by the following:
#
# 1. Truman, David B.
#
# 2. Lietes, Nathan and l~lnik, Constantine
#
# 3. Rogow, Arnold
#
# 4 • M:t.rch, James G
#
# plus copy of preliminary program
#
#
#
# Box 66 folder# 48 laleU.ed "Professional Assoc." contains proposal
#
# from Wm Kornhauser titled "Professional Independence and the Large
#
# Organization" typescript 5 J. plus related material.
# folder# 49 labelled "Personal Security Questionaire" contains
#
# questionaire instruction sheet.
#
# folder# 50 labelled PIC Project" (Pakistan, India, Ceylon) includes
#
# correspondence:
#
# Park, Richard L. TIS 1958 June 15
#
# Thomas, Cecil A. TIS 1958 June 3
#
# carbons of' EB replies, etc.
#
# folder# 51 labelled 'Political Iega.l Theory Group Friedrich" contains
#
# correspondence Friedrich, Cad J. TIS 1954 Oct 6
#
# folder# 52 labelled "Politics and Literature File" contains clipping
#
# f'rom Saturday Review 1963 May 4 title "The Thirties - A Reappraisal"
#
# folder # 53 labelled "How You Will Vote in ' 56 11 contains:
#
# 1. "How You' 11 Vote in ' 56 11 typescript by EB with holo. corr 10( .
# /
#
# plus carbon
# 2. 3 typed carbons of reviesed article 2 . ea.
#
# 3. correspondence mostly with Mr. Jack Stewart of' "This Week
#
# M3.g. fl
#
# 4. Three copies of article as it appeared in This Week M:Lg. of' Los
#
# Angeles Times 1956 M3.y 13
#
# Folder# 54 labelled "Great Dazzling Sun of IA" Holiday M:ig.
#
# 1. carbon typescript of' first second ( 2 copies} 25 / and 23 /
#
# respectively
#
# 2. ty:pescript :t'ina.l draft 18 f.
# 3. correspondence both business and fan
#
# folder # 55 labelled 1tlood Housekeeping: Voting Article"
#
# 1. "The Iron Curtain Around the Ballot Box" typescript with holo.
#
# corr. u / plus carbon of :t'inaJ. draft 14 /.
#
#
#
# Box 66
#
# Box 67
#
# 2. business correspondence includes Miller, Warren TIS 1958 June 19
#
# folder# 56 labelled "The Girls of Waikiki" Beacon copy of "The Beacon"
#
# vol. 1, no. 8 1961 Sept.
#
# folder# 57 labelled "From Gold Rush to Sun Rush" N_ YT M3.g.
#
# tear sheets NY T Mag. 1963 April 14
#
# folder# 58 labelled "Don't Send a Boy" Colliers 1953
#
# 1. typescript of' "Don't Send a Boy" with halo. corr. 22 j
# 2. carbon of' revised version 19} sent to Colliers
#
# 3 • :f'our di:f':f'erent typesc:tj;>ts 18 j., 33 J, 19 f, 24 / respectively
# 4. carbon typescript 30 /.
#
# l
#
# 5. misc. correspondence
#
# folder # 59 labelled '' Communist Propaganda (Sat. Ev. Post Article)"
#
# 1. typescript with halo. corr. 23 /.
#
# 2. misc. correspondence and notes
#
# 3. tear sheets of article plus xerox copy
#
# folder# 60 labelled "Communist Propaganda Article, Assoc. Press"
#
# 1. typescript "Battle for the Minds of Asia" 10 /
#
# 2. McWsh, Archibald TIS 1960 Oct 3
#
# 3. Tear sheets of article and misc. correspondence
#
# folder# 61 labelled "california - Brown-Burdick NY T Supplement"
#
# 1. misc. leaves of ms., misc bus. correspondence tear sheet of
#
# "The Other M:trket by Gov. Brown and EB" N Y T Supplement May 17, 164
#
# 2. Brown, Gov. Edmund G. TUI 2 j 1964 Jan 13
# Jordan, Fred (Press Asst. to Gov) TL9 1964 Mu-ch 26
#
# 3. typescript of "The Two Personalities of California" with holo. corr.
#
# 21.{
# 4. typescript of "The Three Californias: Work, Luck, and Water" 22 /
#
# plus carbon Holiday M:1.g. 4, 1965
#
# 5 • draft of N Y Times Sup. interview between EB and Gov. Brown
#
# typescript with halo. corr. and 2 carbons each a/
#
#
#
# Box 67
#
# Box 68
#
# Box 67
#
# folder# 62 labelled "cavalier M:lg. Series Articles" 1964
#
# 1. typescript of;
#
# a. "The Natural Death of a Strange Cult" with holo. corr.
#
# 5 /. plus carbon 6 /.
#
# b . "Political as Poker" with holo . corr. 5 / .
#
# c. "The Hawkes and Doves over Vietnam" with hole. corr. 10 (
#
# plus carbon and inserts ~j.
# d. "The Bitter Cost of Sweet Charity" with holo. corr. 7).
#
# carbon 9 /.
#
# e. "{he Good and Bad of Next Year" plus 2 carbons with hole. corr.
#
# 3/.
# f. "America: Totally Insane" with holo. corr. 4 /.
#
# title change "What M:l.kes Am. Insane" with holo. 4(.
# g. "Hates and Loves" with holo. corr. 4/ .
# h. "The M:trvelous M9.chine" with halo. corr. 4/. plus 2 carbons
# i. "The Breeding of Politicians" with holo. corr. 5.,,(. plus carbon
#
# 2. copy of cavalier 1965 July and copy of Behavioral Science vol 10
# '""·-· .. ··- ----:---·-·· - - . .. - .. -·
#
# no. 2 April 1965
#
# folder # 63 labelled "Merck Pharmaceutical"
#
# misc. correspondence between Marak Co. and EB 1959 and printed
#
# and mimeo. material about pharmaceuticals and the Ierek Co.
#
# folder# 64 contains misc. political and economic material, all printed
#
# folder# 65 labelled "Henry Kaiser" printed material
#
# folder# 66 printed material ie gov't news letters, etc.
#
#
#
# Boxes 69-72
#
# Burdick, Eugene
#
# . Folder l: Contains student exam booklets and about 35 undergraduate
#
# papers, many with holo. corr. by E.B.-some with typed sheets
#
# of criticism
#
# Folder 2: Contains about 350 J. of mimeo material i.e.
# presentation of papers by economists and political economists
#
# at various meetings and sympo~iums
#
# Form letters and instruction sheets from the University or
#
# Califomia to new fellows and members of academic community
#
# Folder .3t "Political Romanticism: Coleridge and Tolstoy" by Gilbert
#
# Abcasian., PHD thesis., 2 tee; each 207 J. plus TIS from Abcasian, Dec. 1, 195f
# Folder 41 Contains 13 issues of the "Progressive" a periodical publication
#
# 1950-1951 not consecutive
#
# Folder 5tGalleys of THE GREAT EVASIAN by William Appleman Williams
#
# Fo~der 6:Page Proofs ( uncorrected) of CHECKPOilff by Charles W. Thayer
#
# Folder 71 "Anthropology and Industrial Transition" author not indicated
#
# TCC, 213 D. plus Knowles., Frank TLS 1959, August 17.
# Folder 81 Typed excerpts from N .Y. Times ., San Francisco Chronicle on the
#
# subject of Dulles and Eisenhower., newsclipping of Eisenhower
#
# photo and page of comments by EB
#
# Folder 9: Labelled "Bowles., Jobn{Rexall Drugs)-contains correspondence
#
# Bowles., John 2 TIS 1959 Nov. 9, Dec. 4
#
# Carbon of letter from EB to William Lederer 1959 November 20
#
#
#
# Box 73
#
# Burdick, Eugene
#
# Folder 1: labelled "University of California Clientele" NY Times, con-
#
# tains in manuscript-article and misc. correspondence with NY Times, How,t
#
# Chronicle and N of Col officia1s-includingt
#
# TCC-1 each of two different versions-one with bolo. oorr; 2 copies
#
# of a third versiont l with bolo. corr. lld1o ; 14_,J). and 9.J' • and 9
#
# respectively, plus inserts with holo. corr.
#
# Tearsheets of article-3 copies N .Y. Times Magazine section, 1962 May 6
#
# Fold!er 2t labelled l1tJS Navy-Holiday-"-contains correspondence and ms and
#
# reference material including t
#
# 1. ttThe United States Navy"-tcc(3 copies of early draft) 32J ., 37.,P.,
#
# 36). respectivel.y-
#
# 2. TCC(or above title)labelled second draft with holo. corr. 25.Po
#
# 3. TOO/some bolo. corr. and some holo. J). 36.J •
#
# 4. Page correstion inserts., tc/holo. corr. 13...f.
#
# 5. Correspondencet
# s
#
# Rusell, Rear Admiral G.L. TLS 1958 Oct. 3
#
# Wylie., Capt. J .c. TIS 1958 Jlarch 3
# Navo..\
#
# Bur-, Arleigh (Admiral-chief' of baval Operations) TLS 1958 Oct. 6
#
# Fields, Don(Admiral-commander-in-chief-Pacific) TI8 1958 Oct. 9
#
# Folder 3:labelled "Articles-Unfinished"-contains:
#
# l.Outline of an article on the affairs or William Sitgraves Cox, Mid-
# shipman., U .s. Navy o TC 2 J. 1951 May 8
#
# 2. ttJ{uper of th South Seas "-holo. 12J.
#
#
#
# Box 73
#
# Box 74
#
# Burdick, Eugene
#
# Folder 3(continued)
#
# .3."Korea and Classical Warfare"-tc/holo. corr. 15J.
#
# Folder 4: labelled 11True-The Dangers of Paradise"-1963 conta:ins correspondence
#
# and ms including:
#
# 1. tc of original ms with holo. corr. 14J.
# 2 • tee of retyped ms -each 26 J . ( 2 copies )
#
# Folder 5t labelled S .A.C. Article-contains TC of "Abraham Fifty Nine" by Har
#
# vey Wheeler and EB with bolo. corr. BJ.
# correspondence~heeler, Harvey TIS 1958 April 29 plus misc. busmess
#
# letters and EB' s carbons
#
# Folder 6: labelled "Surfing Article-Reader's m.gest"-conta:i.ns mss
#
# 1. 11Surfboarding"-tc/holo. corr. 1 t9 •
# 2.TC/ holo. corr. 14 J. ; TCC/ bolo. corr. 14). plus extra three car-
# bons
#
# .3. "Surf'er"-tc/ bolo. corr. 13 J.; tee March 11 1963 draft 11,.J.
# 4. Notes aned outline, tc/ bolo. corro 6J.
# ~.Two 45 RPM records on surfing plus photos
#
# Printed mate1·ial on surfing and business and misc. correspondence pri-
#
# marily with the Reader's Digest
#
# Folder 7t labelled "S;tan!ord Artici.e"-contains printed material about Stan-
#
# ford University relating to University news and correspondence with
#
# the University Public Relations Office
#
# Folder 8: labelled "Stanford University"-contains::
#
# tc of article 4 J) o
#
# Folder 91 labelled "Sea and Ski Bums, Fall, 156-Holiday Magazine":
#
# l. "The Sea and Ski Bums of Southern ealifornia"-tc/holo. corr. 6.1).
#
# 2. TCC of later draft 9J •
#
#
#
# Box 74
#
# Burdick, Eugene
#
# Folder 1'1: labelled 11Saturday Evening Post"-contains busineas correspondence
#
# with Sat. Evening Post including:
#
# l. Lederer, William 3 TL(carbons) with bolo. corr. 1958 May 25, Oct 16,
#
# Jlllle 8, lTIS-no date
#
# 2. Several carbons of EB 1s letters
#
# Folder llt labelled "iolitical theory and the International Community"-tcc
#
# 14 •
#
# Folder 12: labelled "A Role in Manila"-New Yorker-contains xerox of article
#
# and tearsheete of article
#
# Folder 13: labelled "Articles-rejected" contains:
#
# 1. Telegrams: from NY Times to EB, from EB to NY Times magazine
#
# 2. Typed leaf labelled "California Politics-rewrite"
#
# 3. Tearsheets of the "Politics or Destruction•• Sat. Rev. 1963 Nov. 9
#
# ...
#
# A. TLS from Francis Carney 2/6/64 1 ~-·\ .
#
# B. carbon reply 1/30/64
#
# C. TLS from Martin Kerrlin 7/6/64 1~ .
# D. Carbon to Carney from Burdick 7/12/64 1 --( .
#
# XXI. Artists Civil Rights Assistance Fund Inc.
#
# 1. Printed material on Fund set-up
#
# 2. Printed leaflets for fund-raising
#
# 3 • TLS from Mrs . Warren Mill er ( exec dire ct or ) 12 /17 / 64
#
# (Burdick was on Board of Directors)
#
# XXII. Artificial Organixims
#
# 1. Printed infonnation 2 7 ... ( .
#
# XXIII. Australia Book-Time
#
# A. Halo. outline 2 ,, ( .
#
# B. Correspondence
#
# 1. 6 TLS 1/9/62 - 11/12/62
#
# 2. 5 carbon replies
#
# 3. Telegram 1/31/63
#
# XXIV. Bio-Bihl.
#
# A. Forms (2) - 1962, 1964 for V. of C. supplementary faculty infonnation
#
# B. Carbon of 1963-64 lecture & speeches
#
# C. Lectures & spee~H-es 11/3/60 - 5/4/62
#
#
#
# 6
#
# XXV. Book Reviews by Burdick
#
# A. 3 books on foreign aid - Review - nEnd of the Doubtsu
#
# 1. Typescript with holo. corr. 5
#
# 2. Typescript carbon 6
#
# B. The Road - Austin, typescript carbon (2) 3 . each
#
# C. The Diplomat - Charles Thayer, typescript carbon 2 . i •
#
# D. 6 carbon replies by Burdick to various people
#
# E. Looking For the General - Warren Miller, typescript carbon
#
# F. 1. TLS from Robert Gutivelly 12/19/63 1
#
# 2. TLS from Elizabeth Lawrence 4/16/59 1
#
# 3. TLS from Robert Gutivelly 11/14/63 1
#
# XXVI. Marlon Brando
#
# A. Correspondence
#
# 1. Carbon letters to Brando (8)
#
# 2. TLS from Arthur Brodbeck to Burdick 5/2 0/63 1 - ' .
#
# XA'VII. Burdick-Med i<."nl (Burdick' s heart condition
#
# 1. Carbon letter from Francis Chamberlain to William Kuzeil
#
# 10/10/59 2 .- ; .
#
# 2. Xerox of Burdick' s electrocardiogra phic report
#
# XXVIII. General File
#
# 1. News clippings mentioning Burdick
#
# 2. Fact Jan-Feb 1964 issue
#
# n ..... TLS from Stewart L. Udall (secretary of interior) 9/21/64 1 .(
#
# 4. Several invitations to receptions
#
# 5. TLS from Jack Case 3/14/65 1 .. ! •
#
# 6. Letters involving urhe Battle of Dienbienpher" by Mr. Jules
#
# Roy Y Burdick's enthusiastic comments on it
#
# 7. Printed material on various items
#
# ---
#
#
#
# IL/4l - -
#
# 7
#
# XXX. California tomorrow
#
# I\. ') TLS to EB on subject
#
# D. TLS, carbon .copies from EB
#
# C. 15 items re topic
#
# XIX.n California Race Track
#
# A. 9 items re subject
#
# B. 3 1 ta
#
# XIX.b Photographs of California Democratic Council
#
# A. 2 TLS to EB
#
# n. Mayers desse TLS 6/29/65
#
# C. 5 photos of EB
#
# XXXI. "Capital Punishment"
#
# A. 14 TLS to EB, TLS, carbon copies, of his answers
#
# B. Steve Allen TLS 5/19/60
#
# XXXII. Oftf)ta iH Gool: Carolwood Foundation
#
# A. 1 TLS to EB
#
# B. TLS, curbon copies, of his answers
#
# XXXIII. Cu ptcl i.n Cook
#
# A. 10 TLS to EO from various correspondences
#
# B. 2 ALS to EB
#
# C. TLS, carbon copies, of his letters to various people
#
# XXXIV. Center for Advanced Study in Behavioral Sciences - 9 memoranda
#
# from center
#
# XXXV. Cavalier - correspondence
#
# A. 5 TLS to EB
#
# B. TLS, carbon copies, of EB 1s answers
#
# .:- ....
#
#
#
# 8
#
# XX\_'VI. Center for lltnmmitics
#
# /\. 3 items re center
#
# [l • 2 TLS to I:13
#
# XXXVII. Citizen Exchon~e Corps
#
# !\. 7 i.tems re corps
#
# XXXVIfa. ll'J'JIC Comm i ttce rr (c1bDrct)
#
# A. ') ... 'rLS to EB
#
# B. l TL (CC) from EB
#
# XXXIX. Council ngo:i.nst communist agression, 16 items: form letters from
#
# council, counc .i.l documents.
#
# XL. .Curtis i3rmv11--Gcncrc1l
#
# A. 2:~ TLS to EB 1961/64 from pub.
#
# n. outl inc of nrticla by EB ,, I ... ) . . .
# XLI. CD bcr Cultm·0--Wor ld Publishing Company
#
# I\. l J\LS ,'( :! TT,S to En
#
# 13 • :1 i 1:cms r(~ cybcrnet ics
#
# XLII. Dell 13ook, ~ 'ff.S to ED 1962-63
#
# XLIII. Dc.-1,;Jr1J11ent,1 I. University, carbon of change in sh1tus 1965
#
# XLIV. 1110111,.1s /\.. Dooley Foundation - Correspondence 1962-65, 17 TLS & TALS
#
# to El3 r1.1 fo11nrlc1tion
#
# XLV. Doubleday & Co., Inc.
#
# I\. 7 TLS to El3
#
# B. TL(CC) o[ EI3's answers
#
# XLVI. Dudley, C.:trl 1%1 - 63,
#
# [\ . .5 TLS to EB
#
# 13. TLS. cilrbon cop i cs, of EB .:mswers
#
# XLVII. Fillk Foundation 1961
#
# A.. l TLS to EB
#
# 13. R~port on Palk Foundation Program of training
#
# ·------
#
#
#
# \
#
# 9
#
# XLVIII. FcJrm Labor--Agribusiness
#
# A. pamphlct--Agribusiness cJnd its workers
#
# 13. 2 Stc1tement from Max Mont--telephones
#
# XLIX. Food for peace
#
# I\. Pamphlet
#
# 13. Davis, Edwin TLS to EB 1/19/62
#
# C. TLS of list of members
#
# 9/25/63
#
# L. Joel Pr Fort, 7 items--newsclippings, copies of his statements re
#
# politics.
#
# LI. Francis Amendment--committee to combat communism, 1 copy of amendment
#
# LII. Free speech movement at Berkeley 1965, 29 itcms--pamphlets, news-
#
# clippings, etc.
#
# LIII. Great issues foundcJtion, 2 items; mjmeos of tc of reports
#
# LIV. James Norman Hall, copy of introduction by EB for Jall's The
#
# forgotten One and other tales of the SouthSeas. 7 . : •
#
# A. Second copy with few halo corr. 5 1
#
# 0. 6 TLS to EB from pub. Curtis Brown about introduction
#
# LV. llawa ii, 23 items--ncwsclippings, pamphlets, etc.
#
# LVI. Holj clay M.:ignzine
#
# A. 11 TLS to EB 1963
#
# B. TL(CC) of Eb 1s answers
#
# LVII. Houghton M i:ffl:i.n Co.
#
# A. Pamphlet (new title for 1963) includes Nina 1s Book by EB review
#
# B. TL(CC) of letters from EB
#
# LVIII. Hubert Humphrey, memorandum to Hump11ry supporters, mimeo
#
# LDC. Aldous Huxley--memorial
#
# A. 3 TLS to EB from Carl Pray 1964
#
# B . 3 TLS from EB
#
#
#
# 10
#
# LX~ Independent Producer's Association
#
# A. 3 TLS to EB
#
# B. TL(CC) of Ebts answers
#
# LXI. Indian Caste System
#
# /\.. References on caste
#
# B. Extracts from items re caste
#
# LXII. Idian Project
#
# A. 6 TLS to EB
#
# B. Bergman, Marion TLS 3/2/64
#
# C. 15 items re indians, reprints
#
# D. 18 photos
#
# LXIII. Indonesian
#
# A. 8 items re Inclension Soc. of U .s.
#
# I3. 4 TLS & 1 ALS fromMonne Swatlard--Executive director of Soc.
#
# LXIV. International Child Art Center, 2 items
#
# LXV. International Film Festival
#
# A. 1963 list of events
#
# 13. TL(cc) of EB ts letters to Director.
#
# L)(VI. tfo pnn Trip
#
# 1\ • 2 TLS to EB
#
# n. 2 TL(CC) from EB
#
# L)fVII. Alfred A. Knopt Inc.
#
# A. 5 TLS to EB
#
# B. 3 TL(CC) ;from EB
#
# LA.1VIII. Lane Book Com11<1ny--sunset
#
# A. 2 TLS to EB 1963 from M.B.Lane
#
# B. 2 TL(CC) from EB
#
#
#
# \
#
# 11
#
# LXIX. Lightning, 4 items
#
# LXX. Medical Aid to the Aged Committee, 4 items
#
# LXXI. Mental Research Institute--Palo Alto-5 TLS to EB
#
# A. 2 pamphlets
#
# LXXII. Monterey Army Language School correspondence
#
# A. 8 TLS to EB
#
# B. TL(CC) of his answers
#
# C. John Brahmas TLS 3/25/59
#
# D. Thomas L. Hughes TLS 3/24/59
#
# E. 6 items re subject
#
# LXXIII.
#
# A.
#
# B.
#
# c.
#
# LXXIV.
#
# LXXV.
#
# Monterey Project
#
# 2 TLS to EB from Remsen Dubois Bird
#
# TL(CC) EB's answers
#
# Pamphlet
#
# National Council fro·Civic Responsibility, 3 tiems
#
# William Mullahey
#
# A. 8 TLS and 1 ALS to EB
#
# B.
#
# c.
#
# LXXVI.
#
# A.
#
# B.
#
# LXXVII.
#
# A.
#
# B.
#
# C.
#
# LXXVIII.
#
# A.
#
# B.
#
# TL(CC)s of his answers
#
# Eugene Burdick TLS to William 4/7/64
#
# National Geographic Society, James Cerrelt
#
# 2 TLS to EB from JC
#
# TL(CC) of EB's answers
#
# The Ninth Wave, movie deal--correspondence/contract
#
# 7 TLS to EB
#
# TL(CC)s of his answers
#
# Jerry Wald TLS 9/4/56
#
# W.W. Norton
#
# 5 TLS to EB
#
# 7 TL(CC)s of EB's answers
#
#
#
# LXXIX. ''Nina 's Book" correspondence
#
# A. Agreement with Houghton Mifflin 1961
#
# B. CC's of letters to and from EB
#
# LXXX. Oceanography
#
# A. 1 TIS from "Tap" 3/4/1964
#
# B. Xerox copies of the articles
#
# , LXXXI. Operation Understanding
#
# ·Ji:.i
# L-
#
# A. 2 TLS to EB
#
# B. Copies of memorandum sent out by Sargent Shriver
#
# LXXXII. Oxford University, 3 items
#
# LXXXIII. Pacem in Terris, February 65, 6 pamphlets
#
# LXXXIV. Pacific Area
#
# A. Copy of adress by R. S. Odell, mimeo of ta
#
# B. 2 newsclippings re subject
#
# LXXXV. Pacific Area Travel Association
#
# A. 3 pamphlets_ 1962
#
# B. F. Marvin Blake, TLS 10/30/61
#
# LXXXVI. Pan Am Recommendations, preliminary draft of report to Pan
#
# Am Airways a) .
#
# Box 22
#
# I. ''Lonely American" TV Pending
#
# A. Record - Lonely American Notes" 45 rpn
#
# B. Typescript--some reflections on the intro. o·f "The , Lonely
#
# American" 4~.
#
# C. Mimeo (3 copies) of the filmed series, sample script and story
#
# supplement
#
# 1. Mimeo of final script
#
# I
#
# i
# • i
#
#
#
# \,
#
# 12
#
# ._,.
# II. "Walker, Turnley" 1962-65 -- author of script for the Lonely
#
# American.~ Contains mimeo of T\7 episodes & correspondence with TW-EB's
#
# carbons.
#
# A. Carbon of story development "The Lonely American" by EB & TW 15
#
# III. "Mass Media" #2 --(Fund for the Republic) printed, mimeo, xerox
#
# material, some correspondence - mostly with James Real 1960
#
# IV. "Voluntary Associations"
#
# A. Carbon of notes· for a Discussion of a Beaurocratic Congress 8
#
# B. Coreespondence of a general nature, mostly with Rollock Hoffman
#
# ( 1958-59
#
# C. Beloff, Max - 2 TLS 1/12/59
#
# D. Hofstadter, Richard Carbon typescript 13 11/24/58
#
# V. "Foreign Policy Notes and Articles" all printed material
#
# VI. Misc. Mss & printed material - Fund for the Republic, boluntary
#
# Association in Tuskegee, Alabama
#
# Box 23
#
# I. News Clippings
#
# A. Wall ·Street Journal 11/22/65
#
# B. Literary Clipping Service
#
# 1. 30 envelopes of various clippins 7/12/63 - 7/5/66
#
# II.· Printed material
#
# A. Director of Key government personnel
#
# B. An essay on the Relativity of Categories
#
# C. An International Police Force and Public Opinion
#
# D. Canadian Journal of Econ. & Pol. Sci.
#
# E. Current History October 1955
#
#
#
# II. Printed material continued
#
# 6. 11eontributions to the Jl.nal;}Si.s and Synthesis of Knowledge='
#
# 7. 11Responsibility in Party Finance"
#
# a. "Dictionary of u. s. Militar-J Terw.s II
# 9. 11Addresses of Rhodes Schola:.·s ::
#
# 10. "Problem of Economic Tnstab::.11:'.;ya
#
# 11. 10 catalogues of Australian and New Zealand industry
#
# 12. 10 printed pamphlets on Australian and New Zealand econonics,
#
# tourist, "industry, and political set-u:ps
#
# III. Fund for the Republic
#
# a.. printed material
#
# 1. "Afterthoughts on l,ad.isol1 Ave . Politics a
#
# ·2. Right newsletter
#
# 3. First l'Tational Directory of 11Rightist Groups", ?.:.blications
#
# and sor.ie Individuals in the U3 ( and some forci~ cou.."ltries)
# (2 copies)
#
# 4. Right Feb 1958 and ~~rch 1958
#
# 5 .. 11Ruling Passion" by AnguS .rt.aude xeroxed 3 ✓-
# 6. Tb.e Corporation and the Republic;
#
# 7. Pressure Groups in the US 3 _,f.
# 8. I. F. Stone's Weekly 12/16/57, 1/6/58, 12/9/57
#
# 9. The Nation 1/11/58
#
# 10. Professional Or58-nizations in .Anerican Education
#
# 11. Yesterda.ir.' s Robin Hood: T'a.e Rise and Fall o:f Baltimoir:e 's
#
# Trenton Democratic Club
#
# 12. Mass Media July 1959
#
# 13. 2 copies Freedom to See
#
# 14. State~ent of Frank Stanton 6/12/ 56
#
# 15. The Berlin Story
#
# · 16 .' People and the Pu.blisher
#
#
#
# 17. The Mew Republic 5/19/58
#
# b. articles (typed, xerox, carbon, mi4.eo.)
#
# 1. Fund :f'or the Republic p::.~inted release 2/19/59
#
# 2. "On the HistoricaJ. Bacl:grou..11.d ot: Present Day Disucssions on
#
# Popular Culture a.."l.d ?(ass Communications"
#
# by lee Lowenthal 9/30/53 68~-
#
# 3. Pay Television extension of' 1~e1r.arks of E;::m. Styles Brid£,ras
#
# (M. H.) in U3 Senate 1/23/58
#
# 4. mimeo. ''Where We S""'.:;and :r . 3 -{ ·
#
# 5. printed 111~nace o'f Pay TV" 3 _/.
#
# 6.
# :.i.'
#
# 7/29/57 mimeo. ., he 1--:a.ss i:-edia"
# ~
#
# 2 copies r-.•/ l •
# 7. printed "Freedom to See"
#
# JI
#
# 123-f.
#
# 8. mimeo. "Individual. Freedom and the i~ss 1'-~dia11 2 ccpies
#
# 31,_j ..
#
# 9. "TV News: Reporting or Performingn xerox
#
# 10. The Mass ?t.edia min:.eo. 1-I.
# 11. mimeo. "Taste and the Censor in Televisior." C:'larles Winick
#
# 114 .J.
# 12. xerox
#
# 13. "The Listener"
#
# "Invasion of' the :tr.tind" 18 /.
#
# 3 ✓-
# 14. Printed 11The Characteristics and Policy Roles o:f
#
# Washington Lobby!stsa 2 .,.f.
# 15. typed 11Some P-.celiminary Tnouga.ts 011 t:.::;l :=iar:ip~1let on
#
# Political Action anc. Voluntarism"
#
# 16. mimeo. 11:politica and. citizens 11
#
# 2 ./.
#
# 52 J.
# 17. mimeo. "Polit~cs and Citizens 11 revised 35 /.
#
# i. i1 18. Lobbyist Study mi~eo. ~r { •
#
# 19. mineo. A Biblicg...~ap~y of· Horks on Vclu.11tary As£ociations
#
# and Political Parties in the US ~-2 J. 2 copies
#
#
#
# I 20. typed (partly carbon) "_te::.·ica!l Politics :::.~a. ~.;:1e
# Free Individual :r 36 ) .
#
# 21. typed carbon ·The Volu.11.tary Associatio::1 ::i.110. ?_-:ilitic:::" 11 _/.
# • :1
#
# 22. "The State Society ai:d the Fl"ee !.-:diviclual" 0 ..,,(. t;:r.9ed ca:-0011
#
# 23. mimeo. 11Voluntary Associations So\!iet~r 11 ....... ; .).) .
#
# 25. mimeo. "The I'ia.ture and liatural Eisto::::-y of Pl•ofessim1s.li£mu
# 1
#
# with typed memo :rrore Hallock Hoi'i':1:a.n "?/23/53 2 .A.
# 26. t~d unsigned n:emo to Ealloc!~ Eoftl,:an f1·0:.: c~:.::,:el Eban with
#
# attached outline 7/22/58 2 J.
# 27. xeroxed report to Joe Taylor
#
# 12).
# 28. holo. memo signed by Eal.lock Hoff.r;-:a,n wi ~i:! lf Y Thies cli?ping
#
# dated 9/24/58
#
# 29. xerox 11Voluntary Association 1,1=~::bershil)S c-:i.~ i'-.:. ~:cicu::.
#
# Adults: Eviclcr:.ce fro::·, National Sa.1:.:!_""Jle Six:.-veys '· 11./.
#
# 30. N Y Tili:es cli::_,?i!lg dated. Nov 30 ·i
#
# 31. typed report 4 U \-,.;.,.• ...... ,_,,.Q.~ ',, .• ,'='-.n.10 --'( • --1..t •• v,. _ .. - -
#
# • dated Sept 29 :from ca.r1::-el Eban to !Iallock Eo:fi' .. ;.'.ln .1. ) •
#
# 32. xerox memo 2/r(/58 to I-I I: and I:t:.cci:c J· ... ::.·dic1: i':·or.: :.J.:.m
#
# Rivlcin on the l)roject. of i.mofi'ic:Lal p0i·:e:::.·
#
# 33. photostat then xerox
#
# 5f.
#
# .. n
# :; ./
#
# i
#
# 34. mimeo. 11Profcsnional 1\.ssoc::a.~.:.::. .. :; .. ::: · .. '. :-: · ·· :;.;,,·.::.·.:.· t::.1ti0~··t" '( /.
#
# 35. :printed legal opinio~-... "/cJ..::·2·ccl
#
# 36. mirceo.
#
# -,- 0
# j<.:, ~.
#
# .,...
# ;.• . G~)~~:.;:~•., .. ·1· ..
#
# .i..:..-/.
# . ~ .... ,. ..... _
#
#
#
# IV. correspondence
#
# Box 24
#
# 1. typed carbon to Hallock Ho:f'fman from Don Rivkin ll/10/58
#
# 2. xerox copy of letter t,o H. E lli."'1S igned 9/16/58 with enclosed
#
# clipping f'rcm If Y I.mr Jo,.;.:rnal 9/2/58
#
# 3. TIS to EB f'ror.1 Frank K. Kelly 7/16/57 1.J. with em.osed printed
#
# articles 11Towards I·,:atur-it.y" and 11It' s Tin:e To Take Stock 11 :r:·om
#
# Welevision Kag. July 1957
#
# 4. TI.S to EB from Eric F. Goldman and Frank K. Kelley 2 -f.
# 10/23/57
#
# 5. typed carbon from EB to Robert Hutchins 10/28/57
# /l
#
# 6. typed carbon from EB to Har:ry S. Ashmore 2/9/60 2 /. with
# I'/
#
# enclosed mimeo. "CommifEi.on on the 1Yfa.ss ri~dia 11 4 ,f'.
#
# 1, ~ustralia and New Zealand
#
# 18 items re :pamphlets etc.
#
# 2. i~ss i~dia fund for the republic
#
# 11 items
#
# 3. fund for the republic
#
# 13 items
#
# volunta:7 associations
#
# 4. 21 items misc. reprints, abstracts, etc.
#
# 105 clippings re EB
#
#
#
# Bra.demas, John ( Congressman) TLS 2/.
# ....
#
# 1959 Feb 18
#
# ThOI:i:QSOn, Kenneth H. TLS 1958 Dec 2, 31, 29, 15, 1954 Feb 27.
#
# Muste, A. J. (Editor of "Liberation" British i:;onthly) TIS
#
# Dionisio, Jau.i.i C (Piilli?pine Author) ~LS ~958 Oct 27 plus
#
# carbon of' cha::;it. III of 'his book ACCID:E:l'JT
#
# Brown, Dyke (Vice ?".:es. ::'c:::-d ?ourn::.ation) TIS 1957 Dec 4
#
# Hill, Herbert ( 1.8.oc:r Sec. IIAl',CD) TLS 1957 Oct ::,
#
# Leena.rd , J. Pa.-:.:.l ( ?:.~as . of Am. University of 3e i:.--.r.:.) TLS
#
# 1957, Oct 20
#
# folder 1/: 16 labelled 'h✓oti:c..; Refe1·e;.1ce" c011-tains cha:cts, ou-c.:..ines,
#
# and bibliogra::c,hies on ce::tain aspects of -voting statistics
#
# folder ft 17 labelled "Business Reference" contains bibl.iograpi.1y and
#
# su..>mnary outline en bue i:c_ess t::·e::'ld.S etc.
#
# folder # 18 labelled "Voti:::-J.6 ;-. .:ater·~_2.:._" :::-e bool( },.r.:_ VOTIEG- zs:~::.-'WIOR:
#
# a. contains l)!'inted a::;.d. typed r:ate::cial :re book co::.-:;_te:.:".: plus the
#
# following corres:!_)ondence
#
# 1. Campbell, Angus 2 TIS 1957 Jan 25, 28
#
# 2. Parsons, Talcott 2 TIS 1956 Dec 20, 1957 Jan 23
#
# 3. Ellison, Richa1·d. TIS ~J ~ L .. 1961 P_:9:cil 21
# 1~. Bro.d.beck, Art'c.i.::r J-. 4 ::::'L 1:. d..
#
# b. "Political T11eo::::-y 2.::,,c. Voting Studies" by EB t~r.f8d ca:cbon 25
#
# folder fJ 19 labelled "Ar::ez·::.ca:,.,. Vcting :Behavior ·
#
# a. printed and typed ~atarial, book format outlines and poll graphs
#
# b. correspondence
#
# 1. Modigliani, Franco TIS 1958 April
#
# 2. Remmens, H. E. 2 ::LS 1956 Jan 26,
#
# 3- Parsons, Talco~t TLS 1956 Oct 18
#
# 4. Riecken, Eenry H. TLS 1956 1--:iar l
#
# 22
#
# a· .... ~
# -__ ....
#
# .)• .. i:,~il 14 J.4 ...... .i.;/;;d
#
#
# 	1.pdf
# 	2
# 	3
